# %% [markdown]
# <a href="https://colab.research.google.com/github/poojavvs/simpleprogram/blob/main/Copy_of_01_simple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile prog.c
#
# #include<stdio.h>
#
# int main(void)
# {
#     printf("Hello World!~~~");
#
#     return 0;  // 정상 완료
# }
# Out:
# Overwriting prog.c

# %%
# !ls
# Out:
# hello  prog.c  sample_data

# %%
# !gcc --version
# Out:
# gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
# Copyright (C) 2021 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# !gcc -o hello prog.c

# %%
# !./hello
# Out:
# Hello World!~~~

# %% [markdown]
# **2simple** **interest**

# %%
# %%writefile prog.c
#
# #include<stdio.h>
# int main()
# {
#   int p,n;
#   float r,si;
#   p=1000;
#   n=3;
#   r=8.5;
#   si=p*n*r/100;
#   printf("simple interest=%f",si);
# }
# Out:
# Overwriting prog.c

# %%
# !ls
# Out:
# hello  prog.c  sample_data  si

# %%
# !gcc --version
# Out:
# gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
# Copyright (C) 2021 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# !gcc -o si prog.c

# %%
# !./si
# Out:
# simple interest=255.000000

# %% [markdown]
# **3simple** **interest2**

# %%
# %%writefile prog.c
#
# #include<stdio.h>
# int main()
# {
#   int p,n;
#   float r,si;
#   printf("enter values of p,n,r");
#   scanf("%d%d%f",&p,&n,&r);
#   si=p*n*r/100;
#   printf("%f",si);
# }
# Out:
# Overwriting prog.c

# %%
# !ls
# Out:
# a.out  prog.c  sample_data

# %%
# !gcc  prog.c

# %%
# !./a.out
# Out:
# enter values of p,n,r^C

# %% [markdown]
# //4**sum** of the five digit number

# %%
# %%writefile prog.c
# #include<stdio.h>
# int main()
# {
#   int num,n,a;
#   float sum=0;
#   printf("enter the five digit number\n:");
#   scanf("%d",&num);
#   a=num%10;
#   n=num/10;
#   sum=sum+a;
#   a=num%10;
#   n=num/10;
#   sum=sum+a;
#   a=num%10;
#   n=num/10;
#   sum=sum+a;
#   a=num%10;
#   n=num/10;
#   sum=sum+a;
#   a=num%10;
#   sum=sum+a;
#   printf("sum of five digit number is=%d is %f\n",num,sum);
# }
# Out:
# Overwriting prog.c

# %%
# !ls
# Out:
# prog.c	sample_data

# %%
# !gcc --version
# Out:
# gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
# Copyright (C) 2021 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# !gcc -o sum prog.c

# %%
# !./sum
# Out:
# enter the five digit number
# :
